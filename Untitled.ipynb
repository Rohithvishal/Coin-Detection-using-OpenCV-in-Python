# %% [markdown]
# ### WORKSHOP - 4
# ### Coin Detection using OpenCV in Python
# **Name:** ROHITH J **Reg no:** 212224230232 **Slot:** T1-H15

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('CoinsA.png')

# %% [markdown]
# ## Step 1: Read Image

# %%
imageCopy = image.copy()
plt.imshow(image[:,:,::-1]);
plt.title("Original Image")
plt.show()

# %% [markdown]
# ## Step 2: Convert Image to Grayscale

# %%
imageGray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(12,12))
plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image")
plt.subplot(122); plt.imshow(imageGray,cmap='gray');plt.title("Grayscale Image"); plt.show()

# %% [markdown]
# ## Step 3: Split Image into R,G,B Channels

# %%
imageB, imageG, imageR = cv2.split(image)

# %%
plt.figure(figsize=(20,12))
plt.subplot(141);plt.imshow(image[:,:,::-1]);plt.title("Original Image")
plt.subplot(142);plt.imshow(imageB,cmap='gray');plt.title("Blue Channel")
plt.subplot(143);plt.imshow(imageG,cmap='gray');plt.title("Green Channel")
plt.subplot(144);plt.imshow(imageR,cmap='gray');plt.title("Red Channel");
plt.show()

# %% [markdown]
# ## Step 4: Perform Thresholding

# %%
ret, thresh = cv2.threshold(imageGray, 127, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(thresh, cmap='gray')
plt.title("Threshold Binary Inverse")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 5: Perform morphological operations

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))

# %%
imageDilated1 = cv2.dilate(thresh, kernel, iterations=1)

# %%
imageDilated2 = cv2.dilate(imageDilated1, kernel, iterations=1)

# %%
plt.imshow(imageDilated2,cmap='gray')
plt.title('Dilated Image Iteration 2')
plt.show()

# %%
plt.figure(figsize=(10,8))

plt.subplot(221); plt.imshow(thresh, cmap='gray'); plt.title("Threshold"); plt.axis('off')
plt.subplot(222); plt.imshow(imageDilated1, cmap='gray'); plt.title("Dilated 1"); plt.axis('off')
plt.subplot(223); plt.imshow(imageDilated2, cmap='gray'); plt.title("Dilated 2"); plt.axis('off')

plt.show()

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))

# %%
imageDilated = cv2.dilate(thresh, kernel, iterations=2)

# %%
imageEroded = cv2.erode(imageDilated, kernel, iterations=1)

# %%
plt.imshow(imageEroded,cmap='gray')
plt.title("Eroded Image")
plt.show()

# %% [markdown]
# ## Step 5: Create SimpleBlobDetector

# %%
params = cv2.SimpleBlobDetector_Params()

params.blobColor = 0

params.minDistBetweenBlobs = 2

# Filter by Area.
params.filterByArea = False

# Filter by Circularity
params.filterByCircularity = True
params.minCircularity = 0.8

# Filter by Convexity
params.filterByConvexity = True
params.minConvexity = 0.8

# Filter by Inertia
params.filterByInertia =True
params.minInertiaRatio = 0.8

# %%
detector = cv2.SimpleBlobDetector_create(params)

# %% [markdown]
# ## Step 6: Detect Coins

# %%
keypoints = detector.detect(imageEroded)

# %%
keypoints = detector.detect(imageEroded)

# Draw detected blobs on image
im_with_keypoints = cv2.drawKeypoints(
    imageEroded,
    keypoints,
    np.array([]),
    (0,0,255),
    cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS
)

# Show detected coins
plt.imshow(im_with_keypoints, cmap='gray')
plt.title("Detected Coins")
plt.axis("off")
plt.show()

# Print number of coins
print("Number of coins detected:", len(keypoints))
# Out:
# Number of coins detected: 5
